# %%
import pandas as pd

# %%
df = pd.read_excel ('bank-full.xlsx')

# %%
df
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN                                                NaN
# 1         NaN  This document was exported from Numbers.  Each...
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
# 5         NaN                                 Numbers Sheet Name
# 6         NaN                                                NaN
# 7         NaN                                            Sheet 1
# 8         NaN                                                NaN
#
#            Unnamed: 2            Unnamed: 3
# 0                 NaN                   NaN
# 1                 NaN                   NaN
# 2                 NaN                   NaN
# 3                 NaN                   NaN
# 4                 NaN                   NaN
# 5  Numbers Table Name  Excel Worksheet Name
# ...

# %%
#Comando para importar planilha
df = pd.read_excel ('bank-full.xlsx', sheet_name = 'Sheet 1 - bank-full')

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
#Comando para trazer as primeiras colunas ... ele fincando limitado a visualização de 60
df.head (15)
# Out:
#     age           job   marital  education default  balance housing loan  \
# 0    58    management   married   tertiary      no     2143     yes   no
# 1    44    technician    single  secondary      no       29     yes   no
# 2    33  entrepreneur   married  secondary      no        2     yes  yes
# 3    47   blue-collar   married    unknown      no     1506     yes   no
# 4    33       unknown    single    unknown      no        1      no   no
# 5    35    management   married   tertiary      no      231     yes   no
# 6    28    management    single   tertiary      no      447     yes  yes
# 7    42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8    58       retired   married    primary      no      121     yes   no
# 9    43    technician    single  secondary      no      593     yes   no
# 10   41        admin.  divorced  secondary      no      270     yes   no
# 11   29        admin.    single  secondary      no      390     yes   no
# ...

# %%
#Comando para trazer as primeiras colunas ... ele fincando limitado a visualização de 60
df[:60]
# Out:
#     age            job   marital  education default  balance housing loan  \
# 0    58     management   married   tertiary      no     2143     yes   no
# 1    44     technician    single  secondary      no       29     yes   no
# 2    33   entrepreneur   married  secondary      no        2     yes  yes
# 3    47    blue-collar   married    unknown      no     1506     yes   no
# 4    33        unknown    single    unknown      no        1      no   no
# 5    35     management   married   tertiary      no      231     yes   no
# 6    28     management    single   tertiary      no      447     yes  yes
# 7    42   entrepreneur  divorced   tertiary     yes        2     yes   no
# 8    58        retired   married    primary      no      121     yes   no
# 9    43     technician    single  secondary      no      593     yes   no
# 10   41         admin.  divorced  secondary      no      270     yes   no
# 11   29         admin.    single  secondary      no      390     yes   no
# ...

# %%
#Comando Aleatório onde apresenta uma linha aleatória
df.sample()
# Out:
#        age         job  marital education default  balance housing loan  \
# 40953   52  technician  married  tertiary      no     1785      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome
# 40953  cellular   13   aug       349         1     -1         0  unknown

# %%
#Comando para trazer as ultimas linhas
df.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome
# 45206   cellular   17   nov       977         3     -1         0  unknown
# 45207   cellular   17   nov       456         2     -1         0  unknown
# 45208   cellular   17   nov      1127         5    184         3  success
# 45209  telephone   17   nov       508         4     -1         0  unknown
# 45210   cellular   17   nov       361         2    188        11    other

# %%
#Comando para trazer os nomes das colunas
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome'],
#       dtype='object')

# %%
#Comando para renomear as colunas (dentro do Python)
df.rename(columns={"age":"idade","job":"Profissao"},
          inplace = True)

# %%
df.columns
# Out:
# Index(['idade', 'Profissao', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome'],
#       dtype='object')

# %%
#Faz a conferencia das informações da base
# int64 = numeros - object = texto

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   idade      45211 non-null  int64
#  1   Profissao  45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 5.5+ MB

# %%
#Variaveis que são numericas e aplica calculos estatisticos
#count = qtd de linhas
#mean = média
#std = desvio padrão
#min = minimo 
#25% = do todo tem média de 
#50% = do todo tem a média de
#75% = do todo tem a média de 
#max = maximo

df.describe()
# Out:
#               idade        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# O (letra O em Maisculo)
#unique = unico
#top = valor mais comum 
#freq = quantas x ele aparece 
df.describe(include='O')
# Out:
#           Profissao  marital  education default housing   loan   contact  \
# count         45211    45211      45211   45211   45211  45211     45211
# unique           12        3          4       2       2      2         3
# top     blue-collar  married  secondary      no     yes     no  cellular
# freq           9732    27214      23202   44396   25130  37967     29285
#
#         month poutcome
# count   45211    45211
# unique     12        4
# top       may  unknown
# freq    13766    36959

# %%
#Analisa tudo palavras e numeros
df.describe(include='all')
# Out:
#                idade    Profissao  marital  education default        balance  \
# count   45211.000000        45211    45211      45211   45211   45211.000000
# unique           NaN           12        3          4       2            NaN
# top              NaN  blue-collar  married  secondary      no            NaN
# freq             NaN         9732    27214      23202   44396            NaN
# mean       40.936210          NaN      NaN        NaN     NaN    1362.272058
# std        10.618762          NaN      NaN        NaN     NaN    3044.765829
# min        18.000000          NaN      NaN        NaN     NaN   -8019.000000
# 25%        33.000000          NaN      NaN        NaN     NaN      72.000000
# 50%        39.000000          NaN      NaN        NaN     NaN     448.000000
# 75%        48.000000          NaN      NaN        NaN     NaN    1428.000000
# max        95.000000          NaN      NaN        NaN     NaN  102127.000000
#
# ...

# %%
df['idade']
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: idade, Length: 45211, dtype: int64

# %%
df[['idade','day','Profissao']]
# Out:
#        idade  day     Profissao
# 0         58    5    management
# 1         44    5    technician
# 2         33    5  entrepreneur
# 3         47    5   blue-collar
# 4         33    5       unknown
# ...      ...  ...           ...
# 45206     51   17    technician
# 45207     71   17       retired
# 45208     72   17       retired
# 45209     57   17   blue-collar
# 45210     37   17  entrepreneur
#
# [45211 rows x 3 columns]

# %%
#at = é um localizar]
df.at[0,'idade']
# Out:
# 58

# %%
df.at[45210,'Profissao']
# Out:
# 'entrepreneur'

# %%
#iat = indice ao inves de localizar pelo nome da coluna ele vai pela posição da coluna
#sempre 1 unico valor
df.iat[0,0]
# Out:
# 58

# %%
df.iat[1,2]
# Out:
# 'single'

# %%
#tras a informação completa da linha
df.iloc[1]
# Out:
# idade                44
# Profissao    technician
# marital          single
# education     secondary
# default              no
# balance              29
# housing             yes
# loan                 no
# contact         unknown
# day                   5
# month               may
# duration            151
# campaign              1
# pdays                -1
# previous              0
# poutcome        unknown
# Name: 1, dtype: object

# %%
#mesma ação so que em visão de linha
df.iloc[[1]]
# Out:
#    idade   Profissao marital  education default  balance housing loan  \
# 1     44  technician  single  secondary      no       29     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome
# 1  unknown    5   may       151         1     -1         0  unknown

# %%
df.iloc[1:3]
# Out:
#    idade     Profissao  marital  education default  balance housing loan  \
# 1     44    technician   single  secondary      no       29     yes   no
# 2     33  entrepreneur  married  secondary      no        2     yes  yes
#
#    contact  day month  duration  campaign  pdays  previous poutcome
# 1  unknown    5   may       151         1     -1         0  unknown
# 2  unknown    5   may        76         1     -1         0  unknown

# %%
#localizar coluna
df.iloc[:,1]
# Out:
# 0          management
# 1          technician
# 2        entrepreneur
# 3         blue-collar
# 4             unknown
#              ...
# 45206      technician
# 45207         retired
# 45208         retired
# 45209     blue-collar
# 45210    entrepreneur
# Name: Profissao, Length: 45211, dtype: object

# %%
df.iloc[:,1:3]
# Out:
#           Profissao   marital
# 0        management   married
# 1        technician    single
# 2      entrepreneur   married
# 3       blue-collar   married
# 4           unknown    single
# ...             ...       ...
# 45206    technician   married
# 45207       retired  divorced
# 45208       retired   married
# 45209   blue-collar   married
# 45210  entrepreneur   married
#
# [45211 rows x 2 columns]

# %%
df.iloc[1,0:3]
# Out:
# idade                44
# Profissao    technician
# marital          single
# Name: 1, dtype: object

# %%
#sempre linha e coluna
df.iloc[[0,5,8],0:3]
# Out:
#    idade   Profissao  marital
# 0     58  management  married
# 5     35  management  married
# 8     58     retired  married

# %%
#localizar
df.loc[1]
# Out:
# idade                44
# Profissao    technician
# marital          single
# education     secondary
# default              no
# balance              29
# housing             yes
# loan                 no
# contact         unknown
# day                   5
# month               may
# duration            151
# campaign              1
# pdays                -1
# previous              0
# poutcome        unknown
# Name: 1, dtype: object

# %%
df.loc[[0,1,2]]
# Out:
#    idade     Profissao  marital  education default  balance housing loan  \
# 0     58    management  married   tertiary      no     2143     yes   no
# 1     44    technician   single  secondary      no       29     yes   no
# 2     33  entrepreneur  married  secondary      no        2     yes  yes
#
#    contact  day month  duration  campaign  pdays  previous poutcome
# 0  unknown    5   may       261         1     -1         0  unknown
# 1  unknown    5   may       151         1     -1         0  unknown
# 2  unknown    5   may        76         1     -1         0  unknown

# %%
df.loc[0:2]
# Out:
#    idade     Profissao  marital  education default  balance housing loan  \
# 0     58    management  married   tertiary      no     2143     yes   no
# 1     44    technician   single  secondary      no       29     yes   no
# 2     33  entrepreneur  married  secondary      no        2     yes  yes
#
#    contact  day month  duration  campaign  pdays  previous poutcome
# 0  unknown    5   may       261         1     -1         0  unknown
# 1  unknown    5   may       151         1     -1         0  unknown
# 2  unknown    5   may        76         1     -1         0  unknown

# %%
df.loc[[0,1],['idade','Profissao','default']]
# Out:
#    idade   Profissao default
# 0     58  management      no
# 1     44  technician      no

# %%
df.loc[df.idade > 55]
# Out:
#        idade    Profissao   marital  education default  balance housing loan  \
# 0         58   management   married   tertiary      no     2143     yes   no
# 8         58      retired   married    primary      no      121     yes   no
# 13        58   technician   married    unknown      no       71     yes   no
# 14        57     services   married  secondary      no      162     yes   no
# 17        57  blue-collar   married    primary      no       52     yes   no
# ...      ...          ...       ...        ...     ...      ...     ...  ...
# 45195     68      retired   married  secondary      no     1146      no   no
# 45204     73      retired   married  secondary      no     2850      no   no
# 45207     71      retired  divorced    primary      no     1729      no   no
# 45208     72      retired   married  secondary      no     5715      no   no
# 45209     57  blue-collar   married  secondary      no      668      no   no
#
# ...

# %%
#& = E do excel
df.loc[(df.idade > 55) & (df.Profissao == 'technician')]
# Out:
#        idade   Profissao   marital  education default  balance housing loan  \
# 13        58  technician   married    unknown      no       71     yes   no
# 30        57  technician   married  secondary      no      839      no  yes
# 35        57  technician  divorced  secondary      no       63     yes   no
# 119       57  technician   married    primary      no        0      no   no
# 120       56  technician  divorced    unknown      no       56     yes   no
# ...      ...         ...       ...        ...     ...      ...     ...  ...
# 44567     60  technician  divorced  secondary      no      367      no   no
# 44620     69  technician   married  secondary      no     2661      no   no
# 44638     65  technician   married  secondary      no     2303      no   no
# 44853     58  technician   married  secondary      no       99      no   no
# 45011     59  technician   married  secondary      no        1      no   no
#
# ...

# %%
#value_counts = cont.ses
df.education.value_counts()
# Out:
# education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64

# %%
df['marital'].value_counts()
# Out:
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64

# %%
#mean = média
df.balance.mean()
# Out:
# 1362.2720576850766

# %%
df.duration.mean()
# Out:
# 258.1630797814691

# %%
df[['balance','duration']].mean()
# Out:
# balance     1362.272058
# duration     258.163080
# dtype: float64

# %%
#sum = somar
df.balance.sum()
# Out:
# 61589682

# %%
df[['balance','pdays','duration']].sum()
# Out:
# balance     61589682
# pdays        1817384
# duration    11671811
# dtype: int64

# %%
#unique = unicos 
df.Profissao.unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
#array = tabela

# %%
#nunique = qtd de unicos
df.Profissao.nunique()
# Out:
# 12

# %%
#duplicados
df.duplicated().sum()
# Out:
# 0

# %%
#celula nunca preenchida

df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
#celula vazia
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      1
# balance      0
# housing      1
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
dados1 = {
       'ID':['1','2','3','4','5'],
       'nome':['Paula', 'Claudia', 'Joao', 'Carlos', 'Ana'],
       'sobrenome':['Pereira','Silva','Silveira', 'Bezerra', 'Souza']}

# %%
df1 = pd.DataFrame(dados1, columns = ['ID','nome', 'sobrenome'])

# %%
df1
# Out:
#   ID     nome sobrenome
# 0  1    Paula   Pereira
# 1  2  Claudia     Silva
# 2  3     Joao  Silveira
# 3  4   Carlos   Bezerra
# 4  5      Ana     Souza
